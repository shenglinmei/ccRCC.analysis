# %%
source('lib.r')

# %%
scon=readRDS('normal.kid_conos.rds')

n.ano=readRDS('ano.normal.kid.rds')

# %%
tclu=as.factor(n.ano)
anot.pal <- setNames(sample(rainbow(length(levels(tclu)))),levels(tclu));

anot.palf <- function(n) return(anot.pal)

a2=scon$plotGraph(groups=tclu,plot.na=F,palette=anot.palf,size=0.3,alpha=0.35,font.size = c(4, 4.5))
a2
# Out:
# plot without title

# %%
 options(repr.plot.width = 10, repr.plot.height = 4.5, repr.plot.res = 200)

glist = list()
glist[[ "Collecting duct"]]=c('AQP2','AQP3','GATA2')#,'CLDN8'
glist[["Connecting tubule"]]=c('TMPRSS4','NOS1','SUCNR1') #,'BBOX1'
glist[["Distal convoluted tubule"]]=c('SLC12A3','WNK1','TMEM52B')
glist[["Glomerular podocytes"]]=c('RERG','SPARC','SEMA3G','CLDN5','CR1')
glist[["Loop of Henle" ]]=c('UMOD','SLC12A1','WNK4')
glist[["Proximal tubule-1"]]=c('SLC22A8', 'SLC22A6', 'GSTA1' ,'FABP1','PRODH2' )#'AKR1A1', 'GATM', 'PEPD'
glist[["Proximal tubule-2"]]=c('IL32',  'UGT2A3', 'SOX9' )#, 'CALD1', 'ANPEP'
glist[["Proximal tubule-3" ]]=c('CAV1', 'RERG', 'SPARC', 'BGN' ,'CTFG','CFH')
glist[["Proximal tubule-4"]]=c('KRT7', 'MMP7', 'ITGB6', 'EHF', 'SRCAP')


library(cowplot)

gs = do.call(c,glist)
gs = intersect(gs,colnames(p2$counts))
anoM = tclu
cname=names(anoM)

p=Dotfig(gs,t(pNK$counts)[,cname],anoM[cname],cols = c("blue","white", "red"))

p1=p+xlab('')+ylab('')#+theme(legend.position = 'top')
p1
# Out:
# [1] "blue"
# [1] "white"
# [1] "red"
# plot without title

# %%
gs=c('VCAM1','SLC17A3','SLC22A8','SLC22A6','SOX9','IL32')
b = lapply(sn(gs),function(x) scon$plotGraph(gene=x,title=x,size=0.1))
fig=cowplot::plot_grid(plotlist=b, ncol=3, nrow=2)
fig
# Out:
# plot without title

# %%
conJ = readRDS('Tumor.nkid.conos.rds')
clu  = readRDS('t.ano.rds')

# %%
table(clu)
# Out:
# clu
# ...
#                      685                      418                      386
#     Glomerular podocytes            Loop of Henle        Proximal tubule-1
#                       80                      918                      183
#        Proximal tubule-2        Proximal tubule-3        Proximal tubule-4
#                      879                      392                      788
#                    Tumor
#                     3080

# %%
options(repr.plot.width = 5, repr.plot.height = 5, repr.plot.res = 200)
anot.pal2= anot.pal
anot.pal2['Tumor']='grey'
anot.palf2 <- function(n) return(anot.pal2)
a2=conJ$plotGraph(groups=clu,plot.na=F,palette=anot.palf2,size=0.3,alpha=0.35,font.size = c(4, 4.5),show.legend = FALSE,mark.groups = T)
a2
# Out:
# plot without title

# %%
anof2 = ano.tumor2

features = c('SAA1','SAA2','APOL1','KRT19','APOE','APOC1','ACSM2A','PDK4','VEGFA','NNMT','NDUFA4L2','CLU','CA9')


features = intersect(features,rownames(exp))

cname = intersect(names(anof2),colnames(exp))

stacked.plot(anof2[cname],features,exp,tumor.pal,'F6.tumor.violin.rev.pdf',fig = TRUE)
# Out:
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
#
# ...
